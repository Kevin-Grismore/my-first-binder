# %%
import pandas as pd
import prep

df = prep.prep_all_states()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KEVIN~1.GRI\AppData\Local\Temp/ipykernel_1180/2396649650.py in <module>
#       2 import prep
#       3
# ----> 4 df = prep.prep_all_states()
#
# ~\Documents\GitHub\my-first-binder\prep.py in prep_all_states()
#      90     state_dfs = []
#      91     for state, method in zip(states, methods):
# ---> 92         state_dfs.append(prep_state(state, method))
#      93
#      94     df = pd.concat(state_dfs)
#
# ~\Documents\GitHub\my-first-binder\prep.py in prep_state(state, method)
#      78     x = Prep()
#      79     for file in files:
# ---> 80         dfs.append(getattr(x, method)(file))
#      81
#      82     df = pd.concat(dfs)
#
# TypeError: nebraska() takes 1 positional argument but 2 were given

# %%
df.shape
# Out:
# (182120, 10)

# %%
df.head()
# Out:
#   FirstName MiddleName  LastName Suffix            Street       City State  \
# 0    Jazlyn        NaN    Abeyta    NaN  236 Dillion Ave.   Cheyenne    WY
# 1       Ian        NaN    Aleman    NaN   355 Maestes St,  Johnstown    CO
# 3  Zulaykha        NaN       Ali    NaN      2301 Iola St     Aurora    CO
# 5    Rafael        NaN     Amaro    NaN    1741 Elmira St     Aurora    CO
# 6    Julian        NaN  Arambula    NaN        852 E 1St        Wray    CO
#
#      Zip Hunt Fish
# 0  82007         Y
# 1  80534         Y
# 3  80010         Y
# 5  80010         Y
# 6  80758         Y

# %%
hunt_df = df[df['Hunt'] == 'Y'].drop(columns=['Fish'])
hunt_df.head()
# Out:
#    FirstName MiddleName    LastName Suffix                Street  \
# 0       Joel        NaN     Thomsen    NaN      10647 Wyoming Rd
# 1      Lucas          A  Schumacher    NaN        11039 Rifle Ct
# 2      David        NaN      Harmon    NaN  20992 County Road 22
# 3  Stephanie        NaN      Harmon    NaN  20992 County Road 22
# 4     Gatlin          D       Healy    NaN       2235 E 2300 Ave
#
#             City State    Zip Hunt
# 0       Edgemont    SD  57735    Y
# 1  Commerce City    CO  80022    Y
# 2         Hudson    CO  80642    Y
# 3         Hudson    CO  80642    Y
# 4     Saint Elmo    IL  62458    Y

# %%
fish_df = df[df['Fish'] == 'Y'].drop(columns=['Hunt'])
fish_df.head()
# Out:
#   FirstName MiddleName  LastName Suffix            Street       City State  \
# 0    Jazlyn        NaN    Abeyta    NaN  236 Dillion Ave.   Cheyenne    WY
# 1       Ian        NaN    Aleman    NaN   355 Maestes St,  Johnstown    CO
# 3  Zulaykha        NaN       Ali    NaN      2301 Iola St     Aurora    CO
# 5    Rafael        NaN     Amaro    NaN    1741 Elmira St     Aurora    CO
# 6    Julian        NaN  Arambula    NaN        852 E 1St        Wray    CO
#
#      Zip Fish
# 0  82007    Y
# 1  80534    Y
# 3  80010    Y
# 5  80010    Y
# 6  80758    Y

# %%
columns = list(df.columns)
columns.remove('Hunt')
columns.remove('Fish')

df = hunt_df.merge(fish_df, how='outer', on=columns)
df.shape
# Out:
# (178605, 10)

# %%
df.head()
# Out:
#    FirstName MiddleName    LastName Suffix                Street  \
# 0       Joel        NaN     Thomsen    NaN      10647 Wyoming Rd
# 1      Lucas          A  Schumacher    NaN        11039 Rifle Ct
# 2      David        NaN      Harmon    NaN  20992 County Road 22
# 3  Stephanie        NaN      Harmon    NaN  20992 County Road 22
# 4     Gatlin          D       Healy    NaN       2235 E 2300 Ave
#
#             City State    Zip Hunt Fish
# 0       Edgemont    SD  57735    Y  NaN
# 1  Commerce City    CO  80022    Y  NaN
# 2         Hudson    CO  80642    Y  NaN
# 3         Hudson    CO  80642    Y  NaN
# 4     Saint Elmo    IL  62458    Y  NaN

# %%
df['RecordID'] = df.index + 1
df['Addr2'] = ''
df = df.reindex(columns=['RecordID', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'Street', 'Addr2', 'City', 'State', 'Zip', 'Hunt', 'Fish'])
df = df.fillna('')

# %%
df.to_csv('ne_out.csv', index=False)
