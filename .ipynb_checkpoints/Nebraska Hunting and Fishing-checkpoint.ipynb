# %% [markdown]
# ## Import packages

# %%
import pandas as pd

# %% [markdown]
# ## Read in Antelope file
# Since all the fields with numbers are year or address data, we won't be doing any math. It's safe to read in everything as a string with [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) option dtype.

# %%
antelope = pd.read_csv('Nebraska/Hunt/Antelope.csv', sep='\t', dtype=str)
antelope.head()
# Out:
#   permitYear Permit Type                                           FullName  \
# 0       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 1       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 2       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 3       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 4       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#    firstName middleName    lastName Suffix                street  \
# 0       Joel        NaN     Thomsen    NaN      10647 Wyoming rd
# 1      Lucas          A  Schumacher    NaN        11039 Rifle Ct
# 2      David        NaN      Harmon    NaN  20992 County Road 22
# 3  Stephanie        NaN      Harmon    NaN  20992 County Road 22
# 4     Gatlin          d       Healy    NaN       2235 E 2300 AVE
#
#             city state    zip
# 0       EDGEMONT    SD  57735
# 1  COMMERCE CITY    CO  80022
# 2         HUDSON    CO  80642
# 3         HUDSON    CO  80642
# 4     SAINT ELMO    IL  62458

# %% [markdown]
# ## Fix ZIP Codes
# Some of the zips in the source data are missing zeros at the start, like in row 155. A subset of rows can be selected with [iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html).

# %%
antelope.iloc[[155]]
# Out:
#     permitYear Permit Type                                           FullName  \
# 155       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#     firstName middleName lastName Suffix         street      city state   zip
# 155     Gavin        NaN  Sappier    NaN  610 storer rd  BRADFORD    ME  4410

# %% [markdown]
# To fix this we add zeros to the front of the string to make up the difference using [zfill](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.zfill.html).

# %%
antelope['zip'] = antelope['zip'].str.zfill(5)
antelope.iloc[[155]]
# Out:
#     permitYear Permit Type                                           FullName  \
# 155       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#     firstName middleName lastName Suffix         street      city state    zip
# 155     Gavin        NaN  Sappier    NaN  610 storer rd  BRADFORD    ME  04410

# %% [markdown]
# ## Title Case name and address
# Make all the name and address fields more readable

# %%
antelope['firstName'] = antelope['firstName'].str.title()
antelope['middleName'] = antelope['middleName'].str.title()
antelope['lastName'] = antelope['lastName'].str.title()
antelope['city'] = antelope['city'].str.title()
antelope['street'] = antelope['street'].str.title()
antelope.head()
# Out:
#   permitYear Permit Type                                           FullName  \
# 0       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 1       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 2       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 3       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 4       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#    firstName middleName    lastName Suffix                street  \
# 0       Joel        NaN     Thomsen    NaN      10647 Wyoming Rd
# 1      Lucas          A  Schumacher    NaN        11039 Rifle Ct
# 2      David        NaN      Harmon    NaN  20992 County Road 22
# 3  Stephanie        NaN      Harmon    NaN  20992 County Road 22
# 4     Gatlin          D       Healy    NaN       2235 E 2300 Ave
#
#             city state    zip
# 0       Edgemont    SD  57735
# 1  Commerce City    CO  80022
# 2         Hudson    CO  80642
# 3         Hudson    CO  80642
# 4     Saint Elmo    IL  62458

# %% [markdown]
# ## Add hunt and fish columns
# All data in this file is hunting, so 'Y' for hunt and '' for fish

# %%
antelope['hunt'] = 'Y'
antelope['fish'] = ''
antelope.head()
# Out:
#   permitYear Permit Type                                           FullName  \
# 0       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 1       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 2       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 3       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 4       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#    firstName middleName    lastName Suffix                street  \
# 0       Joel        NaN     Thomsen    NaN      10647 Wyoming Rd
# 1      Lucas          A  Schumacher    NaN        11039 Rifle Ct
# 2      David        NaN      Harmon    NaN  20992 County Road 22
# 3  Stephanie        NaN      Harmon    NaN  20992 County Road 22
# 4     Gatlin          D       Healy    NaN       2235 E 2300 Ave
#
#             city state    zip hunt fish
# 0       Edgemont    SD  57735    Y
# 1  Commerce City    CO  80022    Y
# 2         Hudson    CO  80642    Y
# 3         Hudson    CO  80642    Y
# 4     Saint Elmo    IL  62458    Y

# %% [markdown]
# ## Replace NaNs with empty string
# Also handle blank space in names

# %%
antelope = antelope.fillna('')
antelope = antelope.replace(' ','')
antelope.head()
# Out:
#   permitYear Permit Type                                           FullName  \
# 0       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 1       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 2       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 3       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 4       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#    firstName middleName    lastName Suffix                street  \
# 0       Joel                Thomsen             10647 Wyoming Rd
# 1      Lucas          A  Schumacher               11039 Rifle Ct
# 2      David                 Harmon         20992 County Road 22
# 3  Stephanie                 Harmon         20992 County Road 22
# 4     Gatlin          D       Healy              2235 E 2300 Ave
#
#             city state    zip hunt fish
# 0       Edgemont    SD  57735    Y
# 1  Commerce City    CO  80022    Y
# 2         Hudson    CO  80642    Y
# 3         Hudson    CO  80642    Y
# 4     Saint Elmo    IL  62458    Y

# %% [markdown]
# ## Drop Duplicate Records

# %%
antelope.shape
# Out:
# (1616, 13)

# %%
antelope.drop_duplicates(inplace=True)
antelope.shape
# Out:
# (1616, 13)

# %% [markdown]
# ## Assign Record ID

# %%
antelope['RecordID'] = antelope.index + 1
antelope.head()
# Out:
#   permitYear Permit Type                                           FullName  \
# 0       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 1       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 2       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 3       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 4       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#    firstName middleName    lastName Suffix                street  \
# 0       Joel                Thomsen             10647 Wyoming Rd
# 1      Lucas          A  Schumacher               11039 Rifle Ct
# 2      David                 Harmon         20992 County Road 22
# 3  Stephanie                 Harmon         20992 County Road 22
# 4     Gatlin          D       Healy              2235 E 2300 Ave
#
#             city state    zip hunt fish  RecordID
# 0       Edgemont    SD  57735    Y              1
# 1  Commerce City    CO  80022    Y              2
# 2         Hudson    CO  80642    Y              3
# 3         Hudson    CO  80642    Y              4
# 4     Saint Elmo    IL  62458    Y              5

# %% [markdown]
# ## Add Address 2 and Suffix columns
# to feed ExactTrack

# %%
antelope['addr2'] = ''
antelope.head()
# Out:
#   permitYear Permit Type                                           FullName  \
# 0       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 1       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 2       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 3       2020    Antelope        Non-Resident Landowner Archery-LO- Antelope
# 4       2020    Antelope  Non-Resident-Statewide Antelope Archery- Antelope
#
#    firstName middleName    lastName Suffix                street  \
# 0       Joel                Thomsen             10647 Wyoming Rd
# 1      Lucas          A  Schumacher               11039 Rifle Ct
# 2      David                 Harmon         20992 County Road 22
# 3  Stephanie                 Harmon         20992 County Road 22
# 4     Gatlin          D       Healy              2235 E 2300 Ave
#
#             city state    zip hunt fish  RecordID addr2
# 0       Edgemont    SD  57735    Y              1
# 1  Commerce City    CO  80022    Y              2
# 2         Hudson    CO  80642    Y              3
# 3         Hudson    CO  80642    Y              4
# 4     Saint Elmo    IL  62458    Y              5

# %% [markdown]
# ## Reorder columns
# Using [reindex](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html)

# %%
list(antelope.columns)
# Out:
# ['permitYear',
#  'Permit Type',
#  'FullName',
#  'firstName',
#  'middleName',
#  'lastName',
#  'Suffix',
#  'street',
#  'city',
#  'state',
#  'zip',
#  'hunt',
#  'fish',
#  'RecordID',
#  'addr2']

# %%
antelope = antelope.reindex(columns=['RecordID', 'permitYear', 'Permit Type', 'FullName', 'firstName', 'middleName', 'lastName', 'Suffix', 'street', 'addr2', 'city', 'state', 'zip', 'hunt', 'fish'])
antelope.head()
# Out:
#    RecordID permitYear Permit Type  \
# 0         1       2020    Antelope
# 1         2       2020    Antelope
# 2         3       2020    Antelope
# 3         4       2020    Antelope
# 4         5       2020    Antelope
#
#                                             FullName  firstName middleName  \
# 0        Non-Resident Landowner Archery-LO- Antelope       Joel
# 1        Non-Resident Landowner Archery-LO- Antelope      Lucas          A
# 2        Non-Resident Landowner Archery-LO- Antelope      David
# 3        Non-Resident Landowner Archery-LO- Antelope  Stephanie
# 4  Non-Resident-Statewide Antelope Archery- Antelope     Gatlin          D
#
#      lastName Suffix                street addr2           city state    zip  \
# 0     Thomsen             10647 Wyoming Rd             Edgemont    SD  57735
# 1  Schumacher               11039 Rifle Ct        Commerce City    CO  80022
# 2      Harmon         20992 County Road 22               Hudson    CO  80642
# 3      Harmon         20992 County Road 22               Hudson    CO  80642
# 4       Healy              2235 E 2300 Ave           Saint Elmo    IL  62458
#
#   hunt fish
# 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    Y
